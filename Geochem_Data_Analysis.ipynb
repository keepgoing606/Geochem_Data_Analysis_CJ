# %%
#1导入库
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
rcParams['font.sans-serif'] = ['SimHei']

# %%
#2导入数据
df  = pd.read_csv('Merged_Chem.csv')
df.head()
# Out:
#    Unnamed: 0   Unique ID NTS Sheet  Latitude_NAD83  Longitude_NAD83  Old Zn  \
# 0           0         NaN       NaN             NaN              NaN     NaN
# 1           1  013L781002      013L       54.989093       -62.019071    40.0
# 2           2  013L781003      013L       54.975382       -62.030577    40.0
# 3           3  013L781004      013L       54.976331       -62.044913    46.0
# 4           4  013L781005      013L       54.973541       -62.054790    50.0
#
#    Old Cu  Old Pb  Old Ni  Old Co  ...  New Ti  New Tl  New Tm  New U  New V  \
# 0     NaN     NaN     NaN     NaN  ...     NaN     NaN     NaN    NaN    NaN
# 1    38.0     NaN    43.0    10.0  ...   0.021    0.03    0.10    0.3   31.0
# 2    44.0     NaN    35.0     8.0  ...   0.021    0.03    0.08    0.3   45.0
# 3    30.0     NaN    34.0     8.0  ...   0.023    0.04    0.09    0.3   17.0
# 4    26.0     NaN    22.0     6.0  ...   0.014    0.03    0.12    0.6   34.0
#
#    New W New Y  New Yb  New Zn New Zr
# 0    NaN   NaN     NaN     NaN    NaN
# 1    NaN  6.04    0.64    44.0    0.9
# 2    NaN  5.65    0.49    45.1    1.0
# 3    NaN  7.19    0.64    51.4    0.8
# 4    NaN  8.08    0.74    51.1    0.8
#
# [5 rows x 88 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3442 entries, 0 to 3441
# Data columns (total 88 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          3442 non-null   int64
#  1   Unique ID           3441 non-null   str
#  2   NTS Sheet           3441 non-null   str
#  3   Latitude_NAD83      3441 non-null   float64
#  4   Longitude_NAD83     3441 non-null   float64
#  5   Old Zn              3441 non-null   float64
#  6   Old Cu              3441 non-null   float64
#  7   Old Pb              2143 non-null   float64
#  8   Old Ni              3438 non-null   float64
#  9   Old Co              3416 non-null   float64
#  10  Old Ag              606 non-null    float64
#  11  Old Mn              3441 non-null   float64
#  12  Old Fe              3441 non-null   float64
#  13  Old As              799 non-null    float64
#  14  Old Mo              2496 non-null   float64
#  15  Old F               3433 non-null   float64
#  16  LOI                 3441 non-null   str
#  17  Old Hg              3441 non-null   float64
#  18  Old U               3430 non-null   float64
#  19  Sample Type         3441 non-null   str
#  20  NTS                 3441 non-null   str
#  21  Latitude (NAD 27)   3441 non-null   float64
#  22  Longitude (NAD 27)  3441 non-null   float64
#  23  New Ag              3440 non-null   float64
#  24  New Al              3440 non-null   float64
#  25  New As              2298 non-null   float64
#  26  New Au              2772 non-null   float64
#  27  New B               4 non-null      float64
#  28  New Ba              3440 non-null   float64
#  29  New Be              3241 non-null   float64
#  30  New Bi              2575 non-null   float64
#  31  New Ca              3440 non-null   float64
#  32  New Cd              3440 non-null   float64
#  33  New Ce              3440 non-null   float64
#  34  New Co              3440 non-null   float64
#  35  New Cr              3440 non-null   float64
#  36  New Cs              3440 non-null   float64
#  37  New Cu              3440 non-null   float64
#  38  New Dy              3440 non-null   float64
#  39  New Er              3440 non-null   float64
#  40  New Eu              3440 non-null   float64
#  41  New Fe              3440 non-null   float64
#  42  New Ga              3434 non-null   float64
#  43  New Gd              3440 non-null   float64
#  44  New Ge              948 non-null    float64
#  45  New Hf              1369 non-null   float64
#  46  New Hg              3440 non-null   float64
#  47  New Ho              3440 non-null   float64
#  48  New In              958 non-null    float64
#  49  New K               3427 non-null   float64
#  50  New La              3440 non-null   float64
#  51  New Li              3439 non-null   float64
#  52  New Lu              3439 non-null   float64
#  53  New Mg              3440 non-null   float64
#  54  New Mn              3406 non-null   float64
#  55  New Mo              3440 non-null   float64
#  56  New Na              3439 non-null   float64
#  57  New Nb              3440 non-null   float64
#  58  New Nd              3440 non-null   float64
#  59  New Ni              3440 non-null   float64
#  60  New P               3440 non-null   float64
#  61  New Pb              3440 non-null   float64
#  62  New Pd              22 non-null     float64
#  63  New Pr              3440 non-null   float64
#  64  New Pt              490 non-null    float64
#  65  New Rb              3440 non-null   float64
#  66  New Re              1524 non-null   float64
#  67  New S               3414 non-null   float64
#  68  New Sb              2079 non-null   float64
#  69  New Sc              3440 non-null   float64
#  70  New Se              3373 non-null   float64
#  71  New Sm              3440 non-null   float64
#  72  New Sn              2909 non-null   float64
#  73  New Sr              3440 non-null   float64
#  74  New Ta              2 non-null      float64
#  75  New Tb              3440 non-null   float64
#  76  New Te              897 non-null    float64
#  77  New Th              3368 non-null   float64
#  78  New Ti              3440 non-null   float64
#  79  New Tl              3393 non-null   float64
#  80  New Tm              3439 non-null   float64
#  81  New U               3440 non-null   float64
#  82  New V               3440 non-null   float64
#  83  New W               2056 non-null   float64
#  84  New Y               3440 non-null   float64
#  85  New Yb              3440 non-null   float64
#  86  New Zn              3440 non-null   float64
#  87  New Zr              3355 non-null   float64
# dtypes: float64(82), int64(1), str(5)
# memory usage: 2.3 MB
#        Unnamed: 0  Latitude_NAD83  Longitude_NAD83       Old Zn       Old Cu  \
# count  3442.00000     3441.000000      3441.000000  3441.000000  3441.000000
# mean   1720.50000       55.383663       -63.778378   111.829119    28.005522
# std     993.76414        0.853529         1.451083   104.297344    23.771434
# min       0.00000       54.005243       -66.997815    14.000000     2.000000
# 25%     860.25000       54.646363       -64.884206    62.000000    14.000000
# 50%    1720.50000       55.238594       -63.316447    90.000000    22.000000
# 75%    2580.75000       56.136332       -62.667055   132.000000    34.000000
# max    3441.00000       56.997959       -62.001419  2800.000000   355.000000
#
#             Old Pb       Old Ni       Old Co      Old Ag        Old Mn  ...  \
# count  2143.000000  3438.000000  3416.000000  606.000000   3441.000000  ...
# mean      3.614559    17.569226    10.814110    0.278053    662.333333  ...
# std       2.526390    18.533247    11.908128    0.182716   3055.596946  ...
# min       2.000000     2.000000     2.000000    0.200000     10.000000  ...
# 25%       2.000000     8.000000     5.000000    0.200000     95.000000  ...
# 50%       3.000000    12.000000     8.000000    0.200000    160.000000  ...
# 75%       4.000000    21.000000    12.000000    0.300000    350.000000  ...
# max      38.000000   290.000000   178.000000    1.800000  99999.000000  ...
#
#             New Ti       New Tl       New Tm        New U        New V  \
# count  3440.000000  3393.000000  3439.000000  3440.000000  3440.000000
# mean      0.041443     0.138246     0.354181     3.464738    32.671221
# std       0.030462     0.116209     0.391382     5.752473    18.434130
# min       0.003000     0.020000     0.020000     0.100000     2.000000
# 25%       0.021000     0.070000     0.140000     0.900000    21.000000
# 50%       0.033000     0.110000     0.230000     1.900000    30.000000
# 75%       0.053000     0.170000     0.410000     4.000000    41.000000
# max       0.260000     1.870000     5.220000   130.100000   330.000000
#
#              New W        New Y       New Yb       New Zn       New Zr
# count  2056.000000  3440.000000  3440.000000  3440.000000  3355.000000
# mean      0.438619    24.024858     2.199233   114.758692     1.785902
# std       0.756015    24.319667     2.348694   104.044383     4.569569
# min       0.100000     1.710000     0.150000    12.800000     0.100000
# 25%       0.200000    10.357500     0.880000    64.800000     0.300000
# 50%       0.200000    16.460000     1.430000    94.100000     0.600000
# 75%       0.500000    28.392500     2.590000   135.100000     1.500000
# max      18.400000   300.060000    30.030000  3046.000000   138.800000
#
# [8 rows x 83 columns]

# %%
#3数据预处理
df.columns = df.columns.str.replace(' ', '_').str.replace(':','').str.replace('"','')
if 'Unnamed:_0' in df.columns:
    df = df.drop(columns=['Unnamed:_0'])
#重新保存
df.to_csv('Geochem_clean.csv',index=False)
#统计每一列的缺失值数量和缺失比例
null_counts = df.isnull().sum()
null_ratio = df.isnull().mean()
print(pd.DataFrame({'缺失数量':null_counts,'缺失比例':null_ratio}).sort_values(by='缺失比例',ascending=True).head(30))
# Out:
#                     缺失数量      缺失比例
# Unnamed_0              0  0.000000
# Unique_ID              1  0.000291
# NTS_Sheet              1  0.000291
# Latitude_NAD83         1  0.000291
# Longitude_NAD83        1  0.000291
# Old_Zn                 1  0.000291
# Old_Cu                 1  0.000291
# Old_Mn                 1  0.000291
# Old_Fe                 1  0.000291
# Sample_Type            1  0.000291
# Latitude_(NAD_27)      1  0.000291
# Longitude_(NAD_27)     1  0.000291
# NTS                    1  0.000291
# LOI                    1  0.000291
# Old_Hg                 1  0.000291
# New_Ag                 2  0.000581
# New_Ca                 2  0.000581
# New_Ba                 2  0.000581
# New_Al                 2  0.000581
# New_Hg                 2  0.000581
# New_Ho                 2  0.000581
# New_Gd                 2  0.000581
# New_Fe                 2  0.000581
# New_Eu                 2  0.000581
# New_Er                 2  0.000581
# New_Dy                 2  0.000581
# New_Cu                 2  0.000581
# New_Cs                 2  0.000581
# New_Cr                 2  0.000581
# New_Co                 2  0.000581

# %%
#提取数据质量好的几列
df_sub = df[['Latitude_NAD83','Longitude_NAD83','New_Al','New_Ca','New_Fe','New_Cu','Old_Zn']]
#删除这几列有缺失值的行
df_sub = df_sub.dropna()
print(df_sub.head())
#绘制散点图 看铝铁的关系
df_sub.plot.scatter(x='New_Al',
                    y='New_Fe',
                    s= 1,
                    )
plt.xlabel('New_Al')
plt.ylabel('New_Fe')
plt.title('Geochemical Scatter Plot : Al vs Fe')
plt.xlim(0,4)
plt.ylim(0,15)
plt.savefig('Al_Fe_Scatter.png',dpi=300,bbox_inches='tight')
plt.show()
# Out:
#    Latitude_NAD83  Longitude_NAD83  New_Al  New_Ca  New_Fe  New_Cu  Old_Zn
# 1       54.989093       -62.019071    2.89    0.48    1.06   43.46    40.0
# 2       54.975382       -62.030577    3.22    0.48    2.19   49.32    40.0
# 3       54.976331       -62.044913    2.34    0.56    0.75   33.34    46.0
# 4       54.973541       -62.054790    2.26    0.47    0.84   26.07    50.0
# 5       54.936983       -62.026399    1.89    0.55    0.75   21.40    42.0
